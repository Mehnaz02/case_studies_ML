# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('/home/mehnaz/Downloads/cars.csv')

# %%
data.head()
# Out:
#    S.No              model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am
# 0     1          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1  \
# 1     2      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2     3         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3     4     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     5  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
#
#    gear  carb
# 0     4     4
# 1     4     4
# 2     4     1
# 3     3     1
# 4     3     2

# %%
data.isna().sum()
# Out:
# S.No     0
# model    0
# mpg      0
# cyl      0
# disp     0
# hp       0
# drat     0
# wt       0
# qsec     3
# vs       0
# am       0
# gear     0
# carb     0
# dtype: int64

# %%
car_features=data[['mpg','disp','hp']]

# %%
car_features.columns
# Out:
# Index(['mpg', 'disp', 'hp'], dtype='object')

# %%
car_features
# Out:
#      mpg   disp   hp
# 0   21.0  160.0  110
# 1   21.0  160.0  110
# 2   22.8  108.0   93
# 3   21.4  258.0  110
# 4   18.7  360.0  175
# 5   18.1  225.0  105
# 6   14.3  360.0  245
# 7   24.4  146.7   62
# 8   22.8  140.8   95
# 9   19.2  167.6  123
# 10  17.8  167.6  123
# 11  16.4  275.8  180
# 12  17.3  275.8  180
# 13  15.2  275.8  180
# 14  10.4  472.0  205
# 15  10.4  460.0  215
# 16  14.7  440.0  230
# 17  32.4   78.7   66
# 18  30.4   75.7   52
# 19  33.9   71.1   65
# 20  21.5  120.1   97
# 21  15.5  318.0  150
# 22  15.2  304.0  150
# 23  13.3  350.0  245
# 24  19.2  400.0  175
# 25  27.3   79.0   66
# 26  26.0  120.3   91
# 27  30.4   95.1  113
# 28  15.8  351.0  264
# 29  19.7  145.0  175
# 30  15.0  301.0  335
# 31  21.4  121.0  109

# %%
from sklearn.cluster import KMeans

# %%
model=KMeans(n_clusters=3)

# %%
f1=data1['mpg'].values
f2=data1['disp'].values
f3=data1['hp'].values
x=np.array(list(zip(f1,f2,f3)))

# %%
plt.scatter(f1,f2,f3,c='black')

# %%
model.fit(x)
# Out:
# /home/mehnaz/.local/lib/python3.8/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=3)

# %%
labels=model.predict(x)

# %%
labels
# Out:
# array([0, 0, 0, 1, 2, 1, 2, 0, 0, 0, 0, 1, 1, 1, 2, 2, 2, 0, 0, 0, 0, 1,
#        1, 2, 2, 0, 0, 0, 2, 0, 2, 0], dtype=int32)

# %%
car_features["Cluster"] =labels
# Out:
# /tmp/ipykernel_31364/1350822496.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   car_features["Cluster"] =labels

# %%
cluster_0_data = car_features[car_features["Cluster"] == 0]
cluster_0_data
# Out:
#      mpg   disp   hp  Cluster
# 0   21.0  160.0  110        0
# 1   21.0  160.0  110        0
# 2   22.8  108.0   93        0
# 7   24.4  146.7   62        0
# 8   22.8  140.8   95        0
# 9   19.2  167.6  123        0
# 10  17.8  167.6  123        0
# 17  32.4   78.7   66        0
# 18  30.4   75.7   52        0
# 19  33.9   71.1   65        0
# 20  21.5  120.1   97        0
# 25  27.3   79.0   66        0
# 26  26.0  120.3   91        0
# 27  30.4   95.1  113        0
# 29  19.7  145.0  175        0
# 31  21.4  121.0  109        0

# %%
cluster_1_data = car_features[car_features["Cluster"] == 1]
cluster_1_data
# Out:
#      mpg   disp   hp  Cluster
# 4   18.7  360.0  175        1
# 6   14.3  360.0  245        1
# 14  10.4  472.0  205        1
# 15  10.4  460.0  215        1
# 16  14.7  440.0  230        1
# 23  13.3  350.0  245        1
# 24  19.2  400.0  175        1
# 28  15.8  351.0  264        1
# 30  15.0  301.0  335        1

# %%
cluster_2_data = car_features[car_features["Cluster"] == 2]
cluster_2_data
# Out:
#      mpg   disp   hp  Cluster
# 3   21.4  258.0  110        2
# 5   18.1  225.0  105        2
# 11  16.4  275.8  180        2
# 12  17.3  275.8  180        2
# 13  15.2  275.8  180        2
# 21  15.5  318.0  150        2
# 22  15.2  304.0  150        2

# %%
centroids=model.cluster_centers_

# %%
centroids
# Out:
# array([[ 24.5       , 122.29375   ,  96.875     ],
#        [ 17.01428571, 276.05714286, 150.71428571],
#        [ 14.64444444, 388.22222222, 232.11111111]])

# %%
# 2nd question
from sklearn.cluster import KMeans

# %%
model1=KMeans(n_clusters=5)
model1.fit(x)
labels=model1.predict(x)
# Out:
# /home/mehnaz/.local/lib/python3.8/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
car_features['car_2']=labels
# Out:
# /tmp/ipykernel_31364/3981869293.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   car_features['car_2']=labels

# %%
cluster_1_data = car_features[car_features["car_2"] == 1]
cluster_1_data
# Out:
#      mpg   disp   hp  Cluster  car_2
# 3   21.4  258.0  110        2      1
# 4   18.7  360.0  175        1      1
# 11  16.4  275.8  180        2      1
# 12  17.3  275.8  180        2      1
# 13  15.2  275.8  180        2      1
# 21  15.5  318.0  150        2      1
# 22  15.2  304.0  150        2      1

# %%
cluster_2_data = car_features[car_features["car_2"] == 2]
cluster_2_data
# Out:
#      mpg   disp   hp  Cluster  car_2
# 2   22.8  108.0   93        0      2
# 7   24.4  146.7   62        0      2
# 8   22.8  140.8   95        0      2
# 17  32.4   78.7   66        0      2
# 18  30.4   75.7   52        0      2
# 19  33.9   71.1   65        0      2
# 20  21.5  120.1   97        0      2
# 25  27.3   79.0   66        0      2
# 26  26.0  120.3   91        0      2
# 27  30.4   95.1  113        0      2
# 31  21.4  121.0  109        0      2

# %%
cluster_0_data = car_features[car_features["car_2"] == 0]
cluster_0_data
# Out:
#      mpg   disp   hp  Cluster  car_2
# 0   21.0  160.0  110        0      0
# 1   21.0  160.0  110        0      0
# 5   18.1  225.0  105        2      0
# 9   19.2  167.6  123        0      0
# 10  17.8  167.6  123        0      0
# 29  19.7  145.0  175        0      0
